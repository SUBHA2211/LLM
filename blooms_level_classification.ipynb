# %% [markdown]
# <a href="https://colab.research.google.com/github/SUBHA2211/LLM/blob/main/blooms_level_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install transformers openpyxl pandas

# Step 1: Import Libraries
import pandas as pd
from transformers import pipeline

# Step 2: Load Your Excel File
# Replace with your filename if it's different
file_path = "/content/new_final (1).xlsx"
df = pd.read_excel(file_path)

# Preview the data
df.head()
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
#   Course Code                                          File Link  \
# 0  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 1  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 2  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 3  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 4  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
#
#                                    Coure Name                   File Name  \
# 0  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 1  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 2  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 3  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 4  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
#
#                                             Question  \
# 0  Perform z-score normalization and min-max scal...
# 1   We have a neural network with an input layer ...
# 2   Suppose we need to minimize the following los...
# 3   In linear regression with MAE loss, if we onl...
# 4  A machine learning model gets an accuracy of 9...
#
#                                             Option 1  \
# 0  z-score: [-0.66, -1.03, 1.45, 0.81, -0.66] ,mi...
# 1  \[\n\sum_{i=1}^{l} \left( h_i \cdot h_{i+1} + ...
# 2                                                0.1
# 3                                    Mean of Y_train
# 4                                                yes
#
#                                             Option 2  \
# 0  z-score: [-0.26 -1.54 1.46 0.6 -0.26] ,min-max...
# 1  \[\n\sum_{i=0}^{l} \left( h_i \cdot h_{i+1} + ...
# 2                                                0.5
# 3                                  Median of Y_train
# 4                                                 No
#
#                                             Option 3               Option 4  \
# 0  z-score: [-0.86 ,-1.25, 1.48, 0.7,-0.08] ,min-...      None of the above
# 1  \[\n\sum_{i=1}^{l} \left( h_i \cdot h_{i+1} + ...      None of the above
# 2                                                  1           any a: 0>a>1
# 3                                    Mode of Y_train  Variance of Y_trainNo
# 4                                                NaN                    NaN
#
#   Answer 1  ... Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0        D  ...
# 1        C  ...         NaN         NaN         NaN         NaN         NaN
# 2        B  ...         NaN         NaN         NaN         NaN         NaN
# 3        B  ...         NaN         NaN         NaN         NaN         NaN
# 4        B  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 26 columns]

# %%
df = df.head(100)  # or use df.iloc[:100]

# Step 4: Preview the Selected Data
print("First 100 Rows:")
print(df.head())
# Out:
# First 100 Rows:
#   Course Code                                          File Link  \
# 0  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 1  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 2  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 3  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
# 4  noc20_cs44  https://drive.google.com/file/d/1aruvcr5MwcTcZ...
#
#                                    Coure Name                   File Name  \
# 0  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 1  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 2  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 3  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
# 4  Practical Machine Learning with Tensorflow  noc20_cs44_assigment_1.pdf
#
#                                             Question  \
# 0  Perform z-score normalization and min-max scal...
# 1   We have a neural network with an input layer ...
# 2   Suppose we need to minimize the following los...
# 3   In linear regression with MAE loss, if we onl...
# 4  A machine learning model gets an accuracy of 9...
#
#                                             Option 1  \
# 0  z-score: [-0.66, -1.03, 1.45, 0.81, -0.66] ,mi...
# 1  \[\n\sum_{i=1}^{l} \left( h_i \cdot h_{i+1} + ...
# 2                                                0.1
# 3                                    Mean of Y_train
# 4                                                yes
#
#                                             Option 2  \
# 0  z-score: [-0.26 -1.54 1.46 0.6 -0.26] ,min-max...
# 1  \[\n\sum_{i=0}^{l} \left( h_i \cdot h_{i+1} + ...
# 2                                                0.5
# 3                                  Median of Y_train
# 4                                                 No
#
#                                             Option 3               Option 4  \
# 0  z-score: [-0.86 ,-1.25, 1.48, 0.7,-0.08] ,min-...      None of the above
# 1  \[\n\sum_{i=1}^{l} \left( h_i \cdot h_{i+1} + ...      None of the above
# 2                                                  1           any a: 0>a>1
# 3                                    Mode of Y_train  Variance of Y_trainNo
# 4                                                NaN                    NaN
#
#   Answer 1  ... Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0        D  ...
# 1        C  ...         NaN         NaN         NaN         NaN         NaN
# 2        B  ...         NaN         NaN         NaN         NaN         NaN
# 3        B  ...         NaN         NaN         NaN         NaN         NaN
# 4        B  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 26 columns]

# %%
df.size
# Out:
# 250640

# %%
# Define Bloom's levels as candidate labels
candidate_labels = ["Remember", "Understand", "Apply", "Analyze", "Evaluate", "Create"]

# %%
from transformers import pipeline

# Load the zero-shot classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli",device ="cuda")  # or try: "MoritzLaurer/deberta-v3-large-zeroshot-v2"
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda

# %%
# Define a function to classify Bloom's level
def classify_blooms(question):
  if isinstance(question, str):  # Check if it's a string
    result = classifier(question, candidate_labels, multi_label=False)
    return result['labels'][0]  # Top predicted label
  else:
    return None  # Return None for non-string values


# Apply to the DataFrame
df['Bloom_Level'] = df['Question'].apply(classify_blooms)

# %%
output_path = "/content/questions_with_blooms.xlsx"
df.to_excel(output_path, index=False)

print(f"Saved with Bloom levels at: {output_path}")
# Out:
# Saved with Bloom levels at: /content/questions_with_blooms.xlsx

# %%
df[['Question', 'Bloom_Level']].head()
# Out:
#                                             Question Bloom_Level
# 0  Perform z-score normalization and min-max scal...  Understand
# 1   We have a neural network with an input layer ...  Understand
# 2   Suppose we need to minimize the following los...  Understand
# 3   In linear regression with MAE loss, if we onl...  Understand
# 4  A machine learning model gets an accuracy of 9...  Understand
